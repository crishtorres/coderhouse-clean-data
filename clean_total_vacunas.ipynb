# %%
import pandas as pd

# %%
df = pd.read_csv('dataset_total_vacunas.csv')

df['FECHA_ADMINISTRACION'] = pd.to_datetime(df['FECHA_ADMINISTRACION'], format='%d%b%Y:%H:%M:%S')
ndf = df.drop(['ID_CARGA'], axis=1)
ndf.head(15)

ndf.to_csv('db/clean_total_vacunas.csv')
# Out:
#    FECHA_ADMINISTRACION GRUPO_ETARIO GENERO   VACUNA      TIPO_EFECTOR  \
# 0            2021-01-24      51 a 60      F  Sputnik           Público
# 1            2021-01-24      51 a 60      M  Sputnik           Público
# 2            2021-01-25   30 o menos      F  Sputnik           Privado
# 3            2021-01-25   30 o menos      F  Sputnik           Público
# 4            2021-01-25   30 o menos      F  Sputnik  Público nacional
# 5            2021-01-25   30 o menos      M  Sputnik           Privado
# 6            2021-01-25   30 o menos      M  Sputnik           Público
# 7            2021-01-25      31 a 40      F  Sputnik           Privado
# 8            2021-01-25      31 a 40      F  Sputnik           Público
# 9            2021-01-25      31 a 40      F  Sputnik  Público nacional
# 10           2021-01-25      31 a 40      M  Sputnik           Privado
# 11           2021-01-25      31 a 40      M  Sputnik           Público
# ...
